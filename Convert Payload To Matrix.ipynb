# %%
import json
import pandas as pd
import numpy as np
from feedback import inch_worm, logic, utils

# %%
target = './feedback/ResilientMobilePayload.json'
# target = './feedback/payload.json'
with open(target, 'r') as f:
    payload = json.load(f)

# %%
# INSERT HERE

# %%
# INSERT HERE

# %%
df = utils.get_df_from_payload(WEB_PAYLOAD['poseEstimates'])

# %%
utils.is_confident_detection(df)
# Out:
# False

# %%
utils.transform_keypoint_payload(df)
# Out:
#                   x                                                  \
# part      leftAnkle     leftEar   leftElbow     leftEye     leftHip
# timestep
# 0         292.21048  263.081512  163.945618  253.543655  284.467102
# 1         292.21048  263.081512  163.945618  253.543655  284.467102
# 2         292.21048  263.081512  163.945618  253.543655  284.467102
# 3         292.21048  263.081512  163.945618  253.543655  284.467102
# 4         292.21048  263.081512  163.945618  253.543655  284.467102
# 5         292.21048  263.081512  163.945618  253.543655  284.467102
# 6         292.21048  263.081512  163.945618  253.543655  284.467102
# 7         292.21048  263.081512  163.945618  253.543655  284.467102
# 8         292.21048  263.081512  163.945618  253.543655  284.467102
# 9         292.21048  263.081512  163.945618  253.543655  284.467102
#
#                                                                        ...  \
# ...

# %%
url = 'https://9v04x0kwak.execute-api.us-east-1.amazonaws.com/default/inch-worm'

# %%
input_json = WEB_PAYLOAD

# %%
import requests
response = requests.post(url, json=WEB_PAYLOAD)

# %%
x = response.text

# %%
x
# Out:
# '{"statusCode": 200, "feedback": {"user": {"text-to-speech": "\\"Make sure your shoulders remain directly above your hands.\\""}, "system": {"detection-failing-flag": false}}}'

# %%
type(MOBILE_PAYLOAD)
# Out:
# dict
